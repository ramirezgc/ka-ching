# %%
import pandas as pd
import sqlalchemy as create_engine

# %%
csv_file = "input/unemployment_rate.csv"
unemployment_df = pd.read_csv(csv_file)

unemployment_df
# Out:
#        Series ID       Region Name State  2000  2001  2002  2003  2004  2005  \
# 0     SCABBE1URN  Abbeville County    SC   3.8   6.6   7.7   9.1   8.2   7.7
# 1     LAACAD0URN     Acadia Parish    LA   5.8   6.0   6.3   6.8   5.8   6.1
# 2     VAACCO1URN   Accomack County    VA   3.0   3.4   4.2   4.4   4.7   4.7
# 3     IDADAC1URN        Ada County    ID   3.4   3.9   4.7   4.9   4.1   3.3
# 4     OKADAI1URN      Adair County    OK   3.5   4.1   4.8   7.8   6.2   4.8
# ...          ...               ...   ...   ...   ...   ...   ...   ...   ...
# 3131  COYUMA5URN       Yuma County    CO   2.6   2.3   2.4   3.0   3.2   3.1
# 3132  AZYUMA0URN       Yuma County    AZ  16.3  16.8  16.8  16.8  15.8  15.8
# 3133  TXZAPA5URN     Zapata County    TX   8.0   7.2   8.7   8.8   7.2   6.6
# 3134  TXZAVA7URN     Zavala County    TX  12.3  13.2  14.4  13.8  12.4  11.6
# 3135  SDZIEB7URN    Ziebach County    SD   7.5   7.9   6.2   6.5   7.1   8.0
#
#       2006  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0      8.8  ...  14.2  13.6  12.5  10.6   9.5   7.7   6.9   5.5   4.6   4.2
# 1      3.6  ...   6.5   7.3   6.7   6.0   6.0   5.8   6.9   7.4   5.9   5.4
# 2      4.3  ...   6.5   7.9   8.4   7.9   7.2   6.7   5.5   5.0   4.9   4.1
# 3      2.7  ...   8.9   8.3   7.3   6.2   5.2   4.2   3.7   3.3   2.8   2.4
# 4      4.4  ...   8.0  10.5   9.2   9.1   9.8   8.0   6.1   5.9   5.0   4.4
# ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3131   2.6  ...   3.3   5.6   5.3   5.1   4.8   3.4   2.6   2.1   1.6   2.0
# 3132  14.9  ...  22.9  25.0  24.1  23.8  25.4  22.8  21.6  18.7  17.0  16.9
# 3133   6.1  ...  10.9  10.4   8.1   6.3   6.2   5.2   7.7  10.8   7.3   5.4
# 3134  11.7  ...  14.5  13.9  14.1  13.5  14.5  12.1  11.2  13.9  11.1   9.7
# 3135   5.9  ...   7.0   5.8   6.4   6.9   6.2   5.8   5.0   4.5   5.2   5.0
#
# [3136 rows x 22 columns]

# %%
csv_file= "input/unemployment_rate.csv"

with open(csv_file) as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='input/unemployment_rate.csv' mode='r' encoding='cp1252'>
